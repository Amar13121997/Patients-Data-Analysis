# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\amars\Downloads\healthcare\Hospital ER.csv')

# %%
df.shape
# Out:
# (9216, 11)

# %%
df.describe()
# Out:
#        patient_age  patient_sat_score  patient_waittime
# count  9216.000000        2517.000000       9216.000000
# mean     39.855143           4.992054         35.259874
# std      22.755125           3.138043         14.735323
# min       1.000000           0.000000         10.000000
# 25%      20.000000           2.000000         23.000000
# 50%      39.000000           5.000000         35.000000
# 75%      60.000000           8.000000         48.000000
# max      79.000000          10.000000         60.000000

# %%
(df.isnull().sum()/len(df))*100
# Out:
# date                    0.0
# patient_id              0.0
# patient_gender          0.0
# patient_age             0.0
# patient_sat_score       0.0
# patient_first_inital    0.0
# patient_last_name       0.0
# patient_race            0.0
# patient_admin_flag      0.0
# patient_waittime        0.0
# department_referral     0.0
# dtype: float64

# %%
df['patient_sat_score']=df['patient_sat_score'].fillna(df['patient_sat_score'].mean())

# %%
cat=[f for f in df.columns if df[f].dtype=='O']

# %%
cat
# Out:
# ['date',
#  'patient_id',
#  'patient_gender',
#  'patient_first_inital',
#  'patient_last_name',
#  'patient_race',
#  'department_referral']

# %%
num=[f for f in df.columns if df[f].dtype !='O' and f not in cat]

# %%
num
# Out:
# ['patient_age', 'patient_sat_score', 'patient_admin_flag', 'patient_waittime']

# %%
sns.boxplot(data=df, x='patient_waittime')
plt.show()

# %%
sns.boxplot(data=df, x='patient_age')
plt.show()

# %%
sns.boxplot(data=df, x='patient_sat_score')
plt.show()

# %%
sns.histplot(data=df, x='patient_age')
plt.show()

# %%
sns.histplot(data=df, x='patient_waittime')
plt.show()

# %%
sns.histplot(data=df, x='patient_sat_score')
plt.show()

# %%
num
# Out:
# ['patient_age', 'patient_sat_score', 'patient_admin_flag', 'patient_waittime']

# %%
df.to_csv(r'C:\Users\amars\Downloads\healthcare\HospitalER_1.csv', index=False)
